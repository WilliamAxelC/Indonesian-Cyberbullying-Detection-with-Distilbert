# %% [markdown]
# # Import Library :

# %%
# !pip install optuna nltk
# Out:
# Collecting optuna
#   Downloading optuna-4.6.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: alembic>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (1.17.2)
# Collecting colorlog (from optuna)
#   Downloading colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from optuna) (25.0)
# Requirement already satisfied: sqlalchemy>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from optuna) (2.0.44)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from optuna) (4.67.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from optuna) (6.0.3)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in /usr/local/lib/python3.12/dist-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.2->optuna) (3.2.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic>=1.5.0->optuna) (3.0.3)
# Downloading optuna-4.6.0-py3-none-any.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.7/404.7 kB 9.4 MB/s eta 0:00:00
# Downloading colorlog-6.10.1-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog, optuna
# Successfully installed colorlog-6.10.1 optuna-4.6.0

# %%
import pandas as pd
import numpy as np
import nltk
from nltk.tokenize import word_tokenize

from sklearn.svm import SVC
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from sklearn.model_selection import train_test_split, StratifiedKFold

import matplotlib.pyplot as plt
import seaborn as sns
import optuna

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# # Load Dataset :

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load CSV
file_path = "/content/drive/MyDrive/DistilBERT-7-Mei/combined_dataset.csv"
df = pd.read_csv(file_path)

X = df["clean_text"].astype(str)
y = df["encoded_label"]

# %% [markdown]
# # Train–Val–Test Split

# %%
# ============================================
# PART 2 — Train–Val–Test Split
# ============================================

# Step 1: Pisahkan test 20%
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# Step 2: Dari sisa 80%, ambil 12.5% sebagai validation (~10% total)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.125, random_state=42, stratify=y_temp
)

print("Train size:", len(X_train))
print("Validation size:", len(X_val))
print("Test size:", len(X_test))
# Out:
# Train size: 1445
# Validation size: 207
# Test size: 414

# %% [markdown]
# # Load FastText Embedding (dari Google Drive)

# %%
fasttext_path = "/content/drive/MyDrive/DistilBERT-7-Mei/cc.id.300.vec"

def load_fasttext_embeddings(path):
    print("Loading FastText vectors...")
    embeddings = {}
    with open(path, "r", encoding="utf-8", newline="\n", errors="ignore") as f:
        for line in f:
            values = line.rstrip().split(" ")
            word = values[0]
            vector = np.asarray(values[1:], dtype="float32")
            embeddings[word] = vector
    print("FastText Loaded.")
    return embeddings

fasttext = load_fasttext_embeddings(fasttext_path)
embedding_dim = len(next(iter(fasttext.values())))
print("Embedding dimension:", embedding_dim)
# Out:
# Loading FastText vectors...
# FastText Loaded.
# Embedding dimension: 300

# %% [markdown]
# # Tokenizing + Convert Sentence → Vector

# %%
def sentence_to_vector(sentence, ft_dict, dim):
    tokens = word_tokenize(sentence.lower())
    vecs = [ft_dict[t] for t in tokens if t in ft_dict]

    if len(vecs) == 0:
        return np.zeros(dim)

    return np.mean(vecs, axis=0)

# %% [markdown]
# # Convert Train/Val/Test → Embedding Matrix

# %%
import nltk
nltk.download('punkt_tab')

X_train_vec = np.array([sentence_to_vector(t, fasttext, embedding_dim) for t in X_train])
X_val_vec   = np.array([sentence_to_vector(t, fasttext, embedding_dim) for t in X_val])
X_test_vec  = np.array([sentence_to_vector(t, fasttext, embedding_dim) for t in X_test])

print("Vector shapes:")
print(X_train_vec.shape, X_val_vec.shape, X_test_vec.shape)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Vector shapes:
# (1445, 300) (207, 300) (414, 300)

# %% [markdown]
# # OPTUNA

# %%
from sklearn.metrics import f1_score
from sklearn.svm import SVC
import numpy as np

def objective(trial):
    # Hyperparameters
    C = trial.suggest_float("C", 1e-3, 10, log=True)
    kernel = trial.suggest_categorical("kernel", ["linear", "rbf"])
    gamma = trial.suggest_float("gamma", 1e-4, 1.0, log=True) if kernel == "rbf" else "scale"

    # Train–Validation langsung (tanpa K-Fold)
    model = SVC(
        C=C,
        kernel=kernel,
        gamma=gamma,
        probability=True,
        random_state=42
    )

    model.fit(X_train_vec, y_train)
    preds = model.predict(X_val_vec)

    f1 = f1_score(y_val, preds, average="macro")
    return f1

# %% [markdown]
# # Run Optuna

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=50)

print("Best Params:", study.best_params)
print("Best Val F1:", study.best_value)
# Out:
# [I 2025-11-25 08:47:49,502] A new study created in memory with name: no-name-cc13f554-46f2-4069-8418-6da1b0c1a668
# [I 2025-11-25 08:47:50,831] Trial 0 finished with value: 0.8096689895470384 and parameters: {'C': 0.45103190511155383, 'kernel': 'linear'}. Best is trial 0 with value: 0.8096689895470384.
# [I 2025-11-25 08:47:52,099] Trial 1 finished with value: 0.8309148568133768 and parameters: {'C': 0.5836481822681387, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:53,221] Trial 2 finished with value: 0.35514018691588783 and parameters: {'C': 0.004365182442796533, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:53,966] Trial 3 finished with value: 0.8256443578081005 and parameters: {'C': 1.0302285385078895, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:54,860] Trial 4 finished with value: 0.8096689895470384 and parameters: {'C': 0.42352367521782436, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:56,404] Trial 5 finished with value: 0.35514018691588783 and parameters: {'C': 0.004943198714188787, 'kernel': 'rbf', 'gamma': 0.0006400253952378686}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:57,998] Trial 6 finished with value: 0.35514018691588783 and parameters: {'C': 1.7924481497480191, 'kernel': 'rbf', 'gamma': 0.00019148164965271944}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:47:59,150] Trial 7 finished with value: 0.35514018691588783 and parameters: {'C': 0.007921560440491289, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:48:00,232] Trial 8 finished with value: 0.35514018691588783 and parameters: {'C': 0.005516919682571671, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:48:01,758] Trial 9 finished with value: 0.8096689895470384 and parameters: {'C': 4.359808885410851, 'kernel': 'rbf', 'gamma': 0.021628314709483055}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:48:03,807] Trial 10 finished with value: 0.6125220015086749 and parameters: {'C': 0.06007244447509408, 'kernel': 'rbf', 'gamma': 0.8948521105076491}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:48:05,262] Trial 11 finished with value: 0.8096689895470384 and parameters: {'C': 0.22702377434443352, 'kernel': 'linear'}. Best is trial 1 with value: 0.8309148568133768.
# [I 2025-11-25 08:48:05,887] Trial 12 finished with value: 0.8677879497551628 and parameters: {'C': 8.966816542050767, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:06,536] Trial 13 finished with value: 0.8525641025641026 and parameters: {'C': 7.920090092269917, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:07,269] Trial 14 finished with value: 0.8474503744205397 and parameters: {'C': 5.015986073709681, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:07,875] Trial 15 finished with value: 0.8525641025641026 and parameters: {'C': 7.7673878951025985, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:09,063] Trial 16 finished with value: 0.44342517318824537 and parameters: {'C': 0.05591756322623066, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:09,729] Trial 17 finished with value: 0.8418640183346067 and parameters: {'C': 2.758759660344451, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:11,392] Trial 18 finished with value: 0.35514018691588783 and parameters: {'C': 0.02611654681134146, 'kernel': 'rbf', 'gamma': 0.465039129640428}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:12,527] Trial 19 finished with value: 0.35514018691588783 and parameters: {'C': 0.0012964190810062371, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:13,139] Trial 20 finished with value: 0.8677879497551628 and parameters: {'C': 9.563681462926123, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:13,715] Trial 21 finished with value: 0.8677879497551628 and parameters: {'C': 9.460404552223855, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:14,470] Trial 22 finished with value: 0.8203471552555448 and parameters: {'C': 1.633834767694938, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:15,122] Trial 23 finished with value: 0.8677879497551628 and parameters: {'C': 9.750383697749786, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:15,995] Trial 24 finished with value: 0.8423157493810702 and parameters: {'C': 3.308812403315027, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:17,019] Trial 25 finished with value: 0.830327868852459 and parameters: {'C': 1.2652475860205163, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:19,028] Trial 26 finished with value: 0.35514018691588783 and parameters: {'C': 0.16568784149018298, 'kernel': 'rbf', 'gamma': 0.008683152474027352}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:19,797] Trial 27 finished with value: 0.8470285346492169 and parameters: {'C': 3.126680033504467, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:20,620] Trial 28 finished with value: 0.8256443578081005 and parameters: {'C': 0.8579214963011625, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:21,219] Trial 29 finished with value: 0.8677879497551628 and parameters: {'C': 9.482689081522878, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:22,110] Trial 30 finished with value: 0.8150223402970656 and parameters: {'C': 0.3945806080519954, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:22,810] Trial 31 finished with value: 0.8525641025641026 and parameters: {'C': 6.032533937930202, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:23,414] Trial 32 finished with value: 0.8627320954907162 and parameters: {'C': 9.935113142662786, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:24,116] Trial 33 finished with value: 0.8418640183346067 and parameters: {'C': 2.2382764940784705, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:24,759] Trial 34 finished with value: 0.8525641025641026 and parameters: {'C': 4.470067360191689, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:25,559] Trial 35 finished with value: 0.8256443578081005 and parameters: {'C': 0.8254792003660442, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:26,188] Trial 36 finished with value: 0.8525641025641026 and parameters: {'C': 4.811537016825544, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:26,915] Trial 37 finished with value: 0.8256443578081005 and parameters: {'C': 1.684906220052117, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:28,926] Trial 38 finished with value: 0.8035049288061337 and parameters: {'C': 2.6620778537889733, 'kernel': 'rbf', 'gamma': 0.028392806452346417}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:30,778] Trial 39 finished with value: 0.8309148568133768 and parameters: {'C': 0.5762853177667061, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:31,653] Trial 40 finished with value: 0.8525641025641026 and parameters: {'C': 6.415501430911521, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:32,276] Trial 41 finished with value: 0.8677879497551628 and parameters: {'C': 9.314745766231455, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:32,939] Trial 42 finished with value: 0.8525641025641026 and parameters: {'C': 3.7757801179587025, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:33,528] Trial 43 finished with value: 0.8677879497551628 and parameters: {'C': 9.676275711586142, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:34,175] Trial 44 finished with value: 0.8525641025641026 and parameters: {'C': 6.078218403729261, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:35,730] Trial 45 finished with value: 0.35514018691588783 and parameters: {'C': 6.141855471155083, 'kernel': 'rbf', 'gamma': 0.0023205194254131375}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:36,835] Trial 46 finished with value: 0.35514018691588783 and parameters: {'C': 0.01868497095848587, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:37,624] Trial 47 finished with value: 0.830327868852459 and parameters: {'C': 1.2246392009954055, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:38,343] Trial 48 finished with value: 0.8465750149432159 and parameters: {'C': 2.103756060101871, 'kernel': 'linear'}. Best is trial 12 with value: 0.8677879497551628.
# [I 2025-11-25 08:48:39,466] Trial 49 finished with value: 0.8196864111498258 and parameters: {'C': 3.87650724040203, 'kernel': 'rbf', 'gamma': 0.0957362428115428}. Best is trial 12 with value: 0.8677879497551628.
# Best Params: {'C': 8.966816542050767, 'kernel': 'linear'}
# Best Val F1: 0.8677879497551628

# %% [markdown]
# # Train Final Model dengan Train + Val (FULL TRAINING DATA)

# %%
best_params = study.best_params
gamma = best_params["gamma"] if best_params["kernel"] == "rbf" else "scale"

final_model = SVC(
    C=best_params["C"],
    kernel=best_params["kernel"],
    gamma=gamma,
    probability=True,
    random_state=42
)

# Train menggunakan TRAIN + VAL (digabung)
X_fulltrain = np.concatenate([X_train_vec, X_val_vec])
y_fulltrain = pd.concat([y_train, y_val])

final_model.fit(X_fulltrain, y_fulltrain)
# Out:
# SVC(C=8.966816542050767, kernel='linear', probability=True, random_state=42)

# %% [markdown]
# # FINAL TEST EVALUATION

# %%
y_pred = final_model.predict(X_test_vec)
test_f1 = f1_score(y_test, y_pred, average="macro")


label_map = {0: "Bullying", 1: "Non-bullying"}
class_names = [label_map[i] for i in sorted(label_map.keys())]

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=class_names, digits=4))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("True")
plt.title("Confusion Matrix — Test Set")
plt.show()
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#     Bullying     0.8233    0.8991    0.8595       228
# Non-bullying     0.8606    0.7634    0.8091       186
#
#     accuracy                         0.8382       414
#    macro avg     0.8419    0.8313    0.8343       414
# weighted avg     0.8401    0.8382    0.8369       414

# %% [markdown]
# # Save Model Configuration Summary :

# %%
import json
from pprint import pprint

# Ambil best param dari Optuna
best_C = study.best_params["C"]
best_kernel = study.best_params["kernel"]
best_gamma = gamma  # gamma sudah kita set sebelumnya
EMB_DIM = embedding_dim

experiment_config = {
    "tokenizer": "nltk.word_tokenize",
    "embedding": "fasttext",
    "embedding_dim": EMB_DIM,
    "model": "svm",


    "svm_C": best_C,
    "svm_kernel": best_kernel,
    "svm_gamma": best_gamma,

    "train_size": len(X_train),
    "val_size": len(X_val),
    "test_size": len(X_test)
}

print("\nExperiment Configuration:")
pprint(experiment_config)

print("\nJSON Format:")
print(json.dumps(experiment_config, indent=4))

print("\nFinal Test Macro F1:", f"{test_f1:.4f}")
# Out:
# Experiment Configuration:
# {'embedding': 'fasttext',
#  'embedding_dim': 300,
#  'kfold_splits': 5,
#  'model': 'svm',
#  'svm_C': 8.966816542050767,
#  'svm_gamma': 'scale',
#  'svm_kernel': 'linear',
#  'test_size': 414,
#  'tokenizer': 'nltk.word_tokenize',
#  'train_size': 1445,
#  'use_kfold': True,
#  'val_size': 207}
#
# JSON Format:
# {
#     "tokenizer": "nltk.word_tokenize",
#     "embedding": "fasttext",
#     "embedding_dim": 300,
#     "model": "svm",
#     "use_kfold": true,
#     "kfold_splits": 5,
#     "svm_C": 8.966816542050767,
#     "svm_kernel": "linear",
#     "svm_gamma": "scale",
#     "train_size": 1445,
#     "val_size": 207,
#     "test_size": 414
# }
#
# Final Test Macro F1: 0.8343
